# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)

X=2*np.random.rand(100,1)
y=6+4*X+np.random.randn(100,1)

plt.scatter(X,y)

# %%
print(len(X), X)
# Out:
# 100 [[1.09762701]
#  [1.43037873]
#  [1.20552675]
#  [1.08976637]
#  [0.8473096 ]
#  [1.29178823]
#  [0.87517442]
#  [1.783546  ]
#  [1.92732552]
#  [0.76688304]
#  [1.58345008]
#  [1.05778984]
#  [1.13608912]
#  [1.85119328]
#  [0.14207212]
#  [0.1742586 ]
#  [0.04043679]
#  [1.66523969]
#  [1.5563135 ]
#  [1.7400243 ]
#  [1.95723668]
#  [1.59831713]
#  [0.92295872]
#  [1.56105835]
#  [0.23654885]
#  [1.27984204]
#  [0.28670657]
#  [1.88933783]
#  [1.04369664]
#  [0.82932388]
#  [0.52911122]
#  [1.54846738]
#  [0.91230066]
#  [1.1368679 ]
#  [0.0375796 ]
#  [1.23527099]
#  [1.22419145]
#  [1.23386799]
#  [1.88749616]
#  [1.3636406 ]
#  [0.7190158 ]
#  [0.87406391]
#  [1.39526239]
#  [0.12045094]
#  [1.33353343]
#  [1.34127574]
#  [0.42076512]
#  [0.2578526 ]
#  [0.6308567 ]
#  [0.72742154]
#  [1.14039354]
#  [0.87720303]
#  [1.97674768]
#  [0.20408962]
#  [0.41775351]
#  [0.32261904]
#  [1.30621665]
#  [0.50658321]
#  [0.93262155]
#  [0.48885118]
#  [0.31793917]
#  [0.22075028]
#  [1.31265918]
#  [0.2763659 ]
#  [0.39316472]
#  [0.73745034]
#  [1.64198646]
#  [0.19420255]
#  [1.67588981]
#  [0.19219682]
#  [1.95291893]
#  [0.9373024 ]
#  [1.95352218]
#  [1.20969104]
#  [1.47852716]
#  [0.07837558]
#  [0.56561393]
#  [0.24039312]
#  [0.5922804 ]
#  [0.23745544]
#  [0.63596636]
#  [0.82852599]
#  [0.12829499]
#  [1.38494424]
#  [1.13320291]
#  [0.53077898]
#  [1.04649611]
#  [0.18788102]
#  [1.15189299]
#  [1.8585924 ]
#  [0.6371379 ]
#  [1.33482076]
#  [0.26359572]
#  [1.43265441]
#  [0.57881219]
#  [0.36638272]
#  [1.17302587]
#  [0.04021509]
#  [1.65788006]
#  [0.00939095]]

# %%
print(len(y))
y
# Out:
# 100
# array([[ 9.22535819],
#        [12.62234142],
#        [11.28776945],
#        [ 8.82282178],
#        [10.87749059],
#        [13.06304208],
#        [10.67947726],
#        [12.95425917],
#        [12.63854946],
#        [10.12198388],
#        [11.93062336],
#        [11.45360443],
#        [10.75263147],
#        [14.38141214],
#        [ 6.92465486],
#        [ 7.40360757],
#        [ 6.1722472 ],
#        [14.44682926],
#        [12.3521661 ],
#        [13.36208655],
#        [15.71209743],
#        [11.04550945],
#        [ 8.4213499 ],
#        [13.21363012],
#        [ 5.773072  ],
#        [13.06298936],
#        [ 6.73320732],
#        [12.80989652],
#        [12.0977286 ],
#        [10.79781031],
#        [ 9.98400386],
#        [13.09991417],
#        [ 8.78797697],
#        [12.45753654],
#        [ 5.88231503],
#        [11.74354037],
#        [11.84401775],
#        [10.78046188],
#        [14.164064  ],
#        [12.37676906],
#        [ 9.25248874],
#        [ 8.39685484],
#        [11.87928774],
#        [ 7.80818967],
#        [10.63956586],
#        [11.21546842],
#        [ 7.24790694],
#        [ 8.88067411],
#        [ 9.19572156],
#        [ 9.317148  ],
#        [ 9.79165809],
#        [10.0480613 ],
#        [13.23265804],
#        [ 6.84818904],
#        [ 7.03516797],
#        [ 7.96690944],
#        [11.80145742],
#        [ 7.81803406],
#        [10.1264929 ],
#        [ 6.86234323],
#        [ 5.78049908],
#        [ 7.32239283],
#        [11.41731021],
#        [ 7.74049505],
#        [ 9.95580367],
#        [ 9.89428085],
#        [11.65512361],
#        [ 7.89382649],
#        [11.38765185],
#        [ 6.30720266],
#        [13.74343411],
#        [11.46255233],
#        [13.06933388],
#        [10.01232562],
#        [11.81565611],
#        [ 5.65002405],
#        [ 9.38909162],
#        [ 5.88164098],
#        [ 7.22165293],
#        [ 6.51200171],
#        [ 8.04583298],
#        [11.24363601],
#        [ 7.46260078],
#        [11.6273282 ],
#        [ 9.30737611],
#        [ 8.9674789 ],
#        [ 9.18576908],
#        [ 5.20675299],
#        [11.79560176],
#        [13.75131219],
#        [ 9.46941044],
#        [11.65801069],
#        [ 7.91121351],
#        [11.07959204],
#        [ 7.2810059 ],
#        [ 8.14712541],
#        [ 9.88869381],
#        [ 5.47131059],
#        [12.17598773],
#        [ 6.05504297]])

# %%
plt.scatter(X,y)

# %%
def get_weight_updates(w1,w0,X ,y,learning_rate=0.01):
    N=len(y)
    w1_update=np.zeros_like(w1)
    w0_update=np.zeros_like(w0)
    
    y_pred=np.dot(X,w1.T)+w0
    diff=y-y_pred
    
    w0_factors=np.ones((N,1))
    
    w1_update=-(2/N)*learning_rate*(np.dot(X.T,diff))
    w0_update=-(2/N)*learning_rate*(np.dot(w0_factors.T,diff))
    
    return w1_update, w0_update

# %%
w0=np.zeros((1,1))

w1=np.zeros((1,1))
w1
w1_update=np.zeros_like(w1)
w0_update=np.zeros_like(w0)

w1_update
X.T
diff=y-y_pred
diff
N = len(y)
-(1/N)*0.001*np.dot(w0_factors.T,diff)
-(2/N)*0.001*(np.dot(X.T,diff))
# w0_update=-(2/N)*learning_rate(np.dot(w0_factors.T,diff))
# np.dot(X.T,diff)
# w1_update=-(2/N)*learning_rate(np.dot(X.T,diff))
# get_weight_updates(w1,w0,X ,y,learning_rate=0.01)
# Out:
# array([[-3.78475254e-05]])

# %%
def gradient_descent_steps(X,y,iters=10000):
    
    w0=np.zeros((1,1))
    w1=np.zeros((1,1))
    
    for ind in range(iters):
        w1_update, w0_update=get_weight_updates(w1,w0,X,y,learning_rate=0.01)
        w1=w1-w1_update
        w0=w0-w0_update
        
    return w1,w0

# %%
def get_cost(y,y_pred):
    N=len(y)
    cost=np.sum(np.square(y-y_pred))/N
    return cost


w1, w0=gradient_descent_steps(X,y,iters=1000)


print((w1[0,0], w0[0,0]))
y_pred=w1[0,0]*X+w0
print(get_cost(y,y_pred))
# Out:
# (4.021813642697164, 6.162031224717461)
# 0.9934784315632568

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)

X=2*np.random.rand(100,1)
y=6+4*X+np.random.randn(100,1)

N=len(y)

w0=np.zeros((1,1))
w1=np.zeros((1,1))

w1_update=np.zeros_like(w1)
w0_update=np.zeros_like(w0)

y_pred=np.dot(X,w1.T)+w0
diff=y-y_pred

w0_factors=np.ones((N,1))


for ind in range(1000):
    
    N=len(y)
    w1_update=np.zeros_like(w1)
    w0_update=np.zeros_like(w0)
    
    y_pred=np.dot(X,w1.T)+w0
    diff=y-y_pred
    
    w0_factors=np.ones((N,1))
    
    w1_update=-(2/N)*0.001*(np.dot(X.T,diff))
    w0_update=-(2/N)*0.001*(np.dot(w0_factors.T,diff))
    
    
    w1=w1-w1_update
    w0=w0-w0_update
        
# w1_update=-(2/N)*learning_rate(np.dot(X.T,diff))
# w0_update=-(2/N)*learning_rate(np.dot(w0_factors.T,diff))

# %%
import pandas as pd
import seaborn as sns

from statsmodels.datasets.longley import load_pandas

dfy = load_pandas().endog
dfX = load_pandas().exog
df = pd.concat([dfy, dfX], axis=1)
sns.pairplot(dfX)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn import datasets

diabetes=datasets.load_diabetes()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(diabetes.data, diabetes.target, test_size=0.2, random_state=0)

model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

plt.plot(y_test, y_pred,'.')

x=np.linspace(0,330,100)
y=x
plt.plot(x,y)
plt.show()

# %%
from scipy import stats
from sklearn.datasets import load_boston
# %matplotlib inline

boston=load_boston()

bostonDF=pd.DataFrame(boston.data, columns=boston.f)
